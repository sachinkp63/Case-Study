# %% [markdown]
# # IPL Analysis Batters

# %%
# import the libraries

import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# import file/data

df = pd.read_csv("D:\Data Sets\IPL2025Batters.csv")
df
# Out:
#            Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0        Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1    Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2          Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3         Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4       Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
# ..                 ...  ...   ...      ...  ...  ..   ...    ...  ...     ...
# 151      Khaleel Ahmed  CSK     1       14    2   2    1*      -    2   50.00
# 152       Mohit Sharma   DC     1        8    2   1    1*   1.00    3   33.33
# 153   Donovan Ferreira   DC     1        1    1   0     1   1.00    3   33.33
# 154      Digvesh Singh  LSG     1       13    2   1     1   1.00    3   33.33
# 155     Manoj Bhandage  RCB     1        1    1   0     1   1.00    4   25.00
#
#      100s  50s  4s  6s
# ...

# %%
df.head()
# Out:
#          Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0      Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1  Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2        Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3       Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4     Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
#
#    100s  50s  4s  6s
# 0     1    6  88  21
# 1     0    5  69  38
# 2     0    8  66  19
# 3     0    6  62  24
# 4     1    6  56  37

# %%
# getting the info of he file 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Name  156 non-null    object
#  1   Team         156 non-null    object
#  2   Runs         156 non-null    int64
#  3   Matches      156 non-null    int64
#  4   Inn          156 non-null    int64
#  5   No           156 non-null    int64
#  6   HS           156 non-null    object
#  7   AVG          156 non-null    object
#  8   BF           156 non-null    int64
#  9   SR           156 non-null    float64
#  10  100s         156 non-null    int64
#  11  50s          156 non-null    int64
#  12  4s           156 non-null    int64
#  13  6s           156 non-null    int64
# dtypes: float64(1), int64(9), object(4)
# memory usage: 17.2+ KB

# %%
# getting the data is null or not null

df.isnull().sum()
# Out:
# Player Name    0
# Team           0
# Runs           0
# Matches        0
# Inn            0
# No             0
# HS             0
# AVG            0
# BF             0
# SR             0
# 100s           0
# 50s            0
# 4s             0
# 6s             0
# dtype: int64

# %%
# group by the data using name 

data = df.groupby("Team")
data.head()
# Out:
#              Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF  \
# 0          Sai Sudharsan    GT   759       15   15   1  108*  54.21  486
# 1      Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427
# 2            Virat Kohli   RCB   657       15   15   3   73*  54.75  454
# 3           Shubman Gill    GT   650       15   15   2   93*  50.00  417
# 4         Mitchell Marsh   LSG   627       13   13   0   117  48.23  383
# 5           Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345
# 6       Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350
# 7      Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342
# 8              K L Rahul    DC   539       13   13   3  112*  53.90  360
# 9            Jos Buttler    GT   538       14   13   4   97*  59.78  330
# 10       Nicholas Pooran   LSG   524       14   14   2   87*  43.67  267
# 11      Heinrich Klaasen   SRH   487       13   13   2  105*  44.27  282
# ...

# %%
s = df["Team"].value_counts()
s
# Out:
# Team
# CSK     19
# RR      17
# DC      17
# MI      16
# LSG     15
# PBKS    15
# KKR     15
# GT      14
# RCB     14
# SRH     14
# Name: count, dtype: int64

# %%
s.plot.bar()
# Out:
# <Axes: xlabel='Team'>

# %%
v = df[df["Team"]=="MI"]
v
# Out:
#                   Player Name Team  Runs  Matches  Inn  No   HS    AVG   BF  \
# 1           Surya Kumar Yadav   MI   717       16   16   5  73*  65.18  427
# 15               Rohit Sharma   MI   418       15   15   1   81  29.86  280
# 19             Ryan Rickelton   MI   388       14   14   1  62*  29.85  257
# 25              N Tilak Varma   MI   343       16   13   2   59  31.18  248
# 40                 Naman Dhir   MI   252       16   12   4   46  31.50  138
# 46                 Will Jacks   MI   233       13   11   1   53  23.30  172
# 48              Hardik Pandya   MI   224       15   12   3  48*  24.89  137
# 80             Jonny Bairstow   MI    85        2    2   0   47  42.50   46
# 94               Corbin Bosch   MI    47        2    2   0   27  23.50   32
# 97           Mitchell Santner   MI    40       13    8   6  18*  20.00   33
# 98              Deepak Chahar   MI    37       14    4   3  28*  37.00   25
# ...

# %%
v["AVG"].value_counts()
# Out:
# AVG
# -        3
# 65.18    1
# 29.86    1
# 29.85    1
# 31.18    1
# 31.50    1
# 23.30    1
# 24.89    1
# 42.50    1
# 23.50    1
# 20.00    1
# 37.00    1
# 3.00     1
# 2.00     1
# Name: count, dtype: int64

# %%
v["No"].value_counts()
# Out:
# No
# 1    7
# 0    3
# 3    2
# 5    1
# 2    1
# 4    1
# 6    1
# Name: count, dtype: int64

# %%
v["Matches"].value_counts()
# Out:
# Matches
# 16    4
# 2     4
# 15    2
# 14    2
# 13    2
# 3     1
# 6     1
# Name: count, dtype: int64

# %%
df
# Out:
#            Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0        Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1    Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2          Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3         Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4       Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
# ..                 ...  ...   ...      ...  ...  ..   ...    ...  ...     ...
# 151      Khaleel Ahmed  CSK     1       14    2   2    1*      -    2   50.00
# 152       Mohit Sharma   DC     1        8    2   1    1*   1.00    3   33.33
# 153   Donovan Ferreira   DC     1        1    1   0     1   1.00    3   33.33
# 154      Digvesh Singh  LSG     1       13    2   1     1   1.00    3   33.33
# 155     Manoj Bhandage  RCB     1        1    1   0     1   1.00    4   25.00
#
#      100s  50s  4s  6s
# ...

# %%
v
# Out:
#                   Player Name Team  Runs  Matches  Inn  No   HS    AVG   BF  \
# 1           Surya Kumar Yadav   MI   717       16   16   5  73*  65.18  427
# 15               Rohit Sharma   MI   418       15   15   1   81  29.86  280
# 19             Ryan Rickelton   MI   388       14   14   1  62*  29.85  257
# 25              N Tilak Varma   MI   343       16   13   2   59  31.18  248
# 40                 Naman Dhir   MI   252       16   12   4   46  31.50  138
# 46                 Will Jacks   MI   233       13   11   1   53  23.30  172
# 48              Hardik Pandya   MI   224       15   12   3  48*  24.89  137
# 80             Jonny Bairstow   MI    85        2    2   0   47  42.50   46
# 94               Corbin Bosch   MI    47        2    2   0   27  23.50   32
# 97           Mitchell Santner   MI    40       13    8   6  18*  20.00   33
# 98              Deepak Chahar   MI    37       14    4   3  28*  37.00   25
# ...

# %%
j = v["Inn"].value_counts()
j
# Out:
# Inn
# 2     4
# 1     3
# 12    2
# 16    1
# 15    1
# 14    1
# 13    1
# 11    1
# 8     1
# 4     1
# Name: count, dtype: int64

# %%
u = v["Inn"].unique()
u
# Out:
# array([16, 15, 14, 13, 12, 11,  2,  8,  4,  1])

# %%
y = df["Inn"].value_counts()
y
# Out:
# Inn
# 1     21
# 2     18
# 5     16
# 13    15
# 11    13
# 8      9
# 3      9
# 4      9
# 14     8
# 12     8
# 7      7
# 6      7
# 9      5
# 15     5
# 17     3
# 10     2
# 16     1
# Name: count, dtype: int64

# %%
t = pd.DataFrame(y)
t
# Out:
#      count
# Inn
# 1       21
# 2       18
# 5       16
# 13      15
# 11      13
# 8        9
# 3        9
# 4        9
# 14       8
# 12       8
# 7        7
# 6        7
# 9        5
# 15       5
# 17       3
# 10       2
# 16       1

# %%
import seaborn as sns

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="Runs",hue="Player Name",data=v)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="6s",hue="Player Name",data=v)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="6s",hue="Team",data=df)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="100s",hue="Team",data=df)
plt.show()

# %%
mi = data.get_group('MI')
mi
# Out:
#                   Player Name Team  Runs  Matches  Inn  No   HS    AVG   BF  \
# 1           Surya Kumar Yadav   MI   717       16   16   5  73*  65.18  427
# 15               Rohit Sharma   MI   418       15   15   1   81  29.86  280
# 19             Ryan Rickelton   MI   388       14   14   1  62*  29.85  257
# 25              N Tilak Varma   MI   343       16   13   2   59  31.18  248
# 40                 Naman Dhir   MI   252       16   12   4   46  31.50  138
# 46                 Will Jacks   MI   233       13   11   1   53  23.30  172
# 48              Hardik Pandya   MI   224       15   12   3  48*  24.89  137
# 80             Jonny Bairstow   MI    85        2    2   0   47  42.50   46
# 94               Corbin Bosch   MI    47        2    2   0   27  23.50   32
# 97           Mitchell Santner   MI    40       13    8   6  18*  20.00   33
# 98              Deepak Chahar   MI    37       14    4   3  28*  37.00   25
# ...

# %%
csk = data.get_group('CSK')
csk
# Out:
#              Player Name Team  Runs  Matches  Inn  No   HS    AVG   BF  \
# 22           Shivam Dube  CSK   357       14   14   3   50  32.45  270
# 30       Ravindra Jadeja  CSK   301       14   14   5  77*  33.44  222
# 43          Ayush Mhatre  CSK   240        7    7   0   94  34.29  127
# 47         Dewald Brevis  CSK   225        6    6   0   57  37.50  125
# 54              MS Dhoni  CSK   196       14   13   5  30*  24.50  145
# 55       Rachin Ravindra  CSK   191        8    8   1  65*  27.29  149
# 62          Devon Conway  CSK   156        6    6   0   69  26.00  119
# 68       Ruturaj Gaikwad  CSK   122        5    5   0   63  24.40   81
# 70         Vijay Shankar  CSK   118        6    5   2  69*  39.33   91
# 71            Sam Curran  CSK   114        5    5   0   88  22.80   84
# 83         Shaik Rasheed  CSK    71        5    5   0   27  14.20   63
# 85           Urvil Patel  CSK    68        3    3   0   37  22.67   32
# ...

# %%
rcb = data.get_group('RCB')
rcb
# Out:
#            Player Name Team  Runs  Matches  Inn  No   HS    AVG   BF      SR  \
# 2          Virat Kohli  RCB   657       15   15   3  73*  54.75  454  144.71
# 16           Phil Salt  RCB   403       13   13   1   65  33.58  229  175.98
# 28       Rajat Patidar  RCB   312       15   14   1   64  24.00  217  143.77
# 38       Jitesh Sharma  RCB   261       15   11   4  85*  37.29  148  176.35
# 41    Devdutt Padikkal  RCB   247       10   10   1   61  27.44  164  150.60
# 56           Tim David  RCB   187       12    9   6  50*  62.33  101  185.14
# 72    Liam Livingstone  RCB   112       10    8   1   54  16.00   84  133.33
# 73       Krunal Pandya  RCB   109       15    7   1  73*  18.17   86  126.74
# 77      Mayank Agarwal  RCB    95        4    4   1  41*  31.67   64  148.43
# 84    Romario Shepherd  RCB    70        8    3   1  53*  35.00   24  291.66
# 86       Jacob Bethell  RCB    67        2    2   0   55  33.50   39  171.79
# ...

# %%
gt = data.get_group('GT')
gt
# Out:
#              Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF  \
# 0          Sai Sudharsan   GT   759       15   15   1  108*  54.21  486
# 3           Shubman Gill   GT   650       15   15   2   93*  50.00  417
# 9            Jos Buttler   GT   538       14   13   4   97*  59.78  330
# 33   Sherfane Rutherford   GT   291       13   11   2    46  32.33  185
# 58         Shahrukh Khan   GT   179       15   11   5    57  29.83  100
# 67     Washington Sundar   GT   133        6    5   0    49  26.60   80
# 75         Rahul Tewatia   GT    99       15   12   4   24*  12.38   59
# 96           Rashid Khan   GT    40       15    8   3    12   8.00   28
# 101     Mohd Arshad Khan   GT    23        9    5   3    20  11.50   19
# 105         Kusal Mendis   GT    20        1    1   0    20  20.00   10
# 108       Gerald Coetzee   GT    17        4    2   0    12   8.50   11
# 120        Kagiso Rabada   GT     9        4    2   1    7*   9.00    8
# ...

# %%
pbks = data.get_group('PBKS')
pbks
# Out:
#             Player Name  Team  Runs  Matches  Inn  No   HS    AVG   BF  \
# 5          Shreyas Iyer  PBKS   604       17   17   5  97*  50.33  345
# 7     Prabhsimran Singh  PBKS   549       17   17   0   91  32.29  342
# 12        Priyansh Arya  PBKS   475       17   17   0  103  27.94  265
# 21        Nehal Wadhera  PBKS   369       16   15   3   70  30.75  253
# 24       Shashank Singh  PBKS   350       17   14   7  61*  50.00  228
# 35          Josh Inglis  PBKS   278       11   11   2   73  30.89  171
# 61       Marcus Stoinis  PBKS   160       13   11   5  44*  26.67   86
# 81         Marco Jansen  PBKS    75       14    8   4  34*  18.75   63
# 89   Azmatullah Omarzai  PBKS    57        9    5   1  21*  14.25   41
# 93        Glenn Maxwell  PBKS    48        7    6   0   30   8.00   49
# 115       Harpreet Brar  PBKS    11        8    2   1   7*  11.00   13
# 116     Xavier Bartlett  PBKS    11        4    1   0   11  11.00   15
# ...

# %%
lsg = data.get_group('LSG')
lsg
# Out:
#           Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 4      Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
# 10    Nicholas Pooran  LSG   524       14   14   2   87*  43.67  267  196.25
# 13      Aiden Markram  LSG   445       13   13   0    66  34.23  299  148.82
# 27       Ayush Badoni  LSG   329       14   11   1    74  32.90  222  148.19
# 36       Rishabh Pant  LSG   269       14   13   2  118*  24.45  202  133.16
# 60        Abdul Samad  LSG   164       13   12   4    45  20.50   93  176.34
# 63       David Miller  LSG   153       11   11   6   27*  30.60  120  127.50
# 103        Avesh Khan  LSG    21       13    4   3   19*  21.00   12  175.00
# 106    Shardul Thakur  LSG    18       10    5   2     6   6.00   12  150.00
# 111  Matthew Breetzke  LSG    14        1    1   0    14  14.00   12  116.66
# 114      Ravi Bishnoi  LSG    13       11    3   1    13   6.50   16   81.25
# ...

# %%
dc = data.get_group('DC')
dc
# Out:
#               Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF  \
# 8               K L Rahul   DC   539       13   13   3  112*  53.90  360
# 29          Abishek Porel   DC   301       13   13   1    51  25.08  205
# 31         Tristan Stubbs   DC   300       14   13   7   41*  50.00  199
# 37             Axar Patel   DC   263       12   11   1    43  26.30  167
# 51        Ashutosh Sharma   DC   204       13    9   2   66*  29.14  127
# 52         Faf Du Plessis   DC   202        9    9   0    62  22.44  163
# 53             Karun Nair   DC   198        8    8   0    89  24.75  115
# 65           Vipraj Nigam   DC   142       14    8   1    39  20.29   79
# 69           Sameer Rizvi   DC   121        5    4   1   58*  40.33   79
# 91   Jake Fraser - McGurk   DC    55        6    6   0    38   9.17   52
# 102       Sediqullah Atal   DC    22        1    1   0    22  22.00   16
# 107         Kuldeep Yadav   DC    18       14    5   2     7   6.00   16
# ...

# %%
srh = data.get_group('SRH')
srh
# Out:
#             Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF  \
# 11     Heinrich Klaasen  SRH   487       13   13   2  105*  44.27  282
# 14      Abhishek Sharma  SRH   439       14   13   0   141  33.77  227
# 20          Travis Head  SRH   374       13   12   0    76  31.17  230
# 23         Ishan Kishan  SRH   354       14   13   3  106*  35.40  232
# 45         Aniket Verma  SRH   236       14   12   3    74  26.22  142
# 57   Nitish Kumar Reddy  SRH   182       13   11   3    32  22.75  153
# 76          Pat Cummins  SRH    97       14    9   5   22*  24.25   58
# 79       Kamindu Mendis  SRH    92        5    5   2   32*  30.67   69
# 88      Abhinav Manohar  SRH    61        8    5   0    43  12.20   61
# 104       Harshal Patel  SRH    21       13    4   2   12*  10.50   26
# 113       Atharva Taide  SRH    13        1    1   0    13  13.00    9
# 117      Mohammad Shami  SRH    10        9    4   3    6*  10.00   10
# ...

# %%
kkr = data.get_group('KKR')
kkr
# Out:
#               Player Name Team  Runs  Matches  Inn  No   HS    AVG   BF  \
# 18         Ajinkya Rahane  KKR   390       13   12   1   61  35.45  264
# 32   Angkrish Raghuvanshi  KKR   300       12   11   2   50  33.33  215
# 42           Sunil Narine  KKR   246       12   12   1   44  22.36  144
# 50            Rinku Singh  KKR   206       13   11   4  38*  29.43  134
# 59          Andre Russell  KKR   167       13   10   1  57*  18.56  102
# 64        Quinton De Kock  KKR   152        8    8   1  97*  21.71  117
# 66         Venkatesh Iyer  KKR   142       11    7   0   60  20.29  102
# 78          Manish Pandey  KKR    92        3    3   1   37  46.00   65
# 82     Rahmanullah Gurbaz  KKR    74        5    5   1   35  18.50   53
# 90           Harshit Rana  KKR    57       13    7   3   34  14.25   53
# 95        Ramandeep Singh  KKR    47       11    7   2   22   9.40   35
# 133         Rovman Powell  KKR     5        2    1   0    5   5.00    5
# ...

# %%
rr = data.get_group('RR')
rr
# Out:
#                Player Name Team  Runs  Matches  Inn  No   HS    AVG   BF  \
# 6         Yashasvi Jaiswal   RR   559       14   14   1   75  43.00  350
# 17             Riyan Parag   RR   393       14   14   2   95  32.75  236
# 26             Dhruv Jurel   RR   333       14   13   4   70  37.00  213
# 34            Sanju Samson   RR   285        9    9   1   66  35.63  203
# 39     Vaibhav Suryavanshi   RR   252        7    7   0  101  36.00  122
# 44         Shimron Hetmyer   RR   239       14   13   2   52  21.73  164
# 49             Nitish Rana   RR   217       11   11   1   81  21.70  134
# 74           Shubham Dubey   RR   106        9    8   4  34*  26.50   66
# 87            Jofra Archer   RR    63       12    7   1   30  10.50   50
# 119     Maheesh Theekshana   RR    10       11    4   2    5   5.00   27
# 123      Wanindu Hasaranga   RR     9       11    5   0    4   1.80   15
# 124          Kwena Maphaka   RR     8        2    1   1   8*      -    2
# ...

# %%
df.head(15)
# Out:
#           Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0       Sai Sudharsan    GT   759       15   15   1  108*  54.21  486  156.17
# 1   Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427  167.91
# 2         Virat Kohli   RCB   657       15   15   3   73*  54.75  454  144.71
# 3        Shubman Gill    GT   650       15   15   2   93*  50.00  417  155.87
# 4      Mitchell Marsh   LSG   627       13   13   0   117  48.23  383  163.70
# 5        Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345  175.07
# 6    Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350  159.71
# 7   Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342  160.52
# 8           K L Rahul    DC   539       13   13   3  112*  53.90  360  149.72
# 9         Jos Buttler    GT   538       14   13   4   97*  59.78  330  163.03
# 10    Nicholas Pooran   LSG   524       14   14   2   87*  43.67  267  196.25
# ...

# %%
mi_runss = mi['Runs'].sum()
mi_runss
# Out:
# np.int64(2802)

# %%
csk_runss = csk['Runs'].sum()
csk_runss
# Out:
# np.int64(2315)

# %%
rcb_runss = rcb['Runs'].sum()
rcb_runss
# Out:
# np.int64(2539)

# %%
gt_runss = gt['Runs'].sum()
gt_runss
# Out:
# np.int64(2766)

# %%
pbks_runss = pbks['Runs'].sum()
pbks_runss
# Out:
# np.int64(3000)

# %%
kkr_runss = kkr[r'Runs'].sum()
kkr_runss
# Out:
# np.int64(1886)

# %%
rr_runss = rr['Runs'].sum()
rr_runss
# Out:
# np.int64(2496)

# %%
dc_runss = dc['Runs'].sum()
dc_runss
# Out:
# np.int64(2386)

# %%
srh_runss = srh['Runs'].sum()
srh_runss
# Out:
# np.int64(2378)

# %%
lsg_runss = lsg['Runs'].sum()
lsg_runss
# Out:
# np.int64(2598)

# %%
runs = [mi_runss,csk_runss,rcb_runss,gt_runss,pbks_runss,kkr_runss,rr_runss,dc_runss,srh_runss,lsg_runss]
runs
# Out:
# [np.int64(2802),
#  np.int64(2315),
#  np.int64(2539),
#  np.int64(2766),
#  np.int64(3000),
#  np.int64(1886),
#  np.int64(2496),
#  np.int64(2386),
#  np.int64(2378),
#  np.int64(2598)]

# %%
winner = max(runs)
winner
# Out:
# np.int64(3000)

# %%
mi_runs = mi.loc[mi['Runs'].idxmax(),['Player Name','Runs']]
mi_runs
# Out:
# Player Name    Surya Kumar Yadav
# Runs                         717
# Name: 1, dtype: object

# %%
csk_runs = csk.loc[csk['Runs'].idxmax(),['Player Name','Runs']]
csk_runs
# Out:
# Player Name    Shivam Dube
# Runs                   357
# Name: 22, dtype: object

# %%
rcb_runs = rcb.loc[rcb['Runs'].idxmax(),['Player Name','Runs']]
rcb_runs
# Out:
# Player Name    Virat Kohli
# Runs                   657
# Name: 2, dtype: object

# %%
gt_runs = gt.loc[gt['Runs'].idxmax(),['Player Name','Runs']]
gt_runs
# Out:
# Player Name    Sai Sudharsan
# Runs                     759
# Name: 0, dtype: object

# %%
pbks_runs = pbks.loc[pbks['Runs'].idxmax(),['Player Name','Runs']]
pbks_runs
# Out:
# Player Name    Shreyas Iyer
# Runs                    604
# Name: 5, dtype: object

# %%
lsg_runs = lsg.loc[lsg['Runs'].idxmax(),['Player Name','Runs']]
lsg_runs
# Out:
# Player Name    Mitchell Marsh
# Runs                      627
# Name: 4, dtype: object

# %%
rr_runs = rr.loc[rr['Runs'].idxmax(),['Player Name','Runs']]
rr_runs
# Out:
# Player Name    Yashasvi Jaiswal
# Runs                        559
# Name: 6, dtype: object

# %%
kkr_runs = kkr.loc[kkr['Runs'].idxmax(),['Player Name','Runs']]
kkr_runs
# Out:
# Player Name    Ajinkya Rahane
# Runs                      390
# Name: 18, dtype: object

# %%
srh_runs = srh.loc[srh['Runs'].idxmax(),['Player Name','Runs']]
srh_runs
# Out:
# Player Name    Heinrich Klaasen
# Runs                        487
# Name: 11, dtype: object

# %%
dc_runs = dc.loc[dc['Runs'].idxmax(),['Player Name','Runs']]
dc_runs
# Out:
# Player Name    K L Rahul
# Runs                 539
# Name: 8, dtype: object

# %%
runss = pd.Series({
    "MI":mi_runss,
    "CSK":csk_runss,
    "RCB":rcb_runss,
    "GT":gt_runss,
    "PBKS":pbks_runss,
    "LSG":lsg_runss,
    "KKR":kkr_runss,
    "RR":rr_runss,
    "DC":dc_runss,
    "SRH":srh_runss
})
runss
# Out:
# MI      2802
# CSK     2315
# RCB     2539
# GT      2766
# PBKS    3000
# LSG     2598
# KKR     1886
# RR      2496
# DC      2386
# SRH     2378
# dtype: int64

# %%
runss.plot(kind='bar',title='Runs Comparison')
plt.show()

# %%
runss.plot(kind='line',marker='o',title='Runs Trend')
plt.xticks(range(len(runss)), runss.index)
plt.show()

# %%
runss.plot(kind="pie", autopct="%1.1f%%", title="Run Share")
# Out:
# <Axes: title={'center': 'Run Share'}>

# %%
runss.plot(kind="barh", title="Horizontal Comparison")
# Out:
# <Axes: title={'center': 'Horizontal Comparison'}>

# %%
df
# Out:
#            Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0        Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1    Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2          Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3         Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4       Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
# ..                 ...  ...   ...      ...  ...  ..   ...    ...  ...     ...
# 151      Khaleel Ahmed  CSK     1       14    2   2    1*      -    2   50.00
# 152       Mohit Sharma   DC     1        8    2   1    1*   1.00    3   33.33
# 153   Donovan Ferreira   DC     1        1    1   0     1   1.00    3   33.33
# 154      Digvesh Singh  LSG     1       13    2   1     1   1.00    3   33.33
# 155     Manoj Bhandage  RCB     1        1    1   0     1   1.00    4   25.00
#
#      100s  50s  4s  6s
# ...

# %%
df['SR'] = (df['Runs'] / df['Balls']) * 100

# %%
df
# Out:
#            Player Name Team  Runs  Matches  Inn  No    HS    AVG   BF      SR  \
# 0        Sai Sudharsan   GT   759       15   15   1  108*  54.21  486  156.17
# 1    Surya Kumar Yadav   MI   717       16   16   5   73*  65.18  427  167.91
# 2          Virat Kohli  RCB   657       15   15   3   73*  54.75  454  144.71
# 3         Shubman Gill   GT   650       15   15   2   93*  50.00  417  155.87
# 4       Mitchell Marsh  LSG   627       13   13   0   117  48.23  383  163.70
# ..                 ...  ...   ...      ...  ...  ..   ...    ...  ...     ...
# 151      Khaleel Ahmed  CSK     1       14    2   2    1*      -    2   50.00
# 152       Mohit Sharma   DC     1        8    2   1    1*   1.00    3   33.33
# 153   Donovan Ferreira   DC     1        1    1   0     1   1.00    3   33.33
# 154      Digvesh Singh  LSG     1       13    2   1     1   1.00    3   33.33
# 155     Manoj Bhandage  RCB     1        1    1   0     1   1.00    4   25.00
#
#      100s  50s  4s  6s
# ...

# %%
top_players = df.groupby('Player Name')['Runs'].sum().sort_values(ascending=False).head(5)

# %%
top_players
# Out:
# Player Name
# Sai Sudharsan        759
# Surya Kumar Yadav    717
# Virat Kohli          657
# Shubman Gill         650
# Mitchell Marsh       627
# Name: Runs, dtype: int64

# %%
import seaborn as sns

# %%
sns.set(style="dark")

top_players = df.groupby('Player Name')['Runs'].sum().sort_values(ascending=False).head(5)

top_players.plot(kind='bar')
plt.title("Top 5 Run Scorers")
plt.xlabel("Players")
plt.ylabel("Runs")
plt.xticks(rotation=45)
plt.show()

# %%
top_strikers = df.groupby('SR')['6s'].sum().sort_values(ascending=False).head(5)
top_strikers
# Out:
# SR
# 196.25    40
# 175.07    39
# 167.91    38
# 163.70    37
# 160.52    30
# Name: 6s, dtype: int64

# %%
top_sixes = df.groupby('6s')['BF'].sum().sort_values(ascending=False)
top_sixes
# Out:
# 6s
# 21    1369
# 4     1103
# 22    1021
# 14     899
# 24     869
# 11     779
# 15     715
# 16     621
# 19     598
# 28     577
# 13     568
# 25     547
# 17     530
# 8      523
# 12     487
# 10     471
# 38     427
# 18     413
# 20     406
# 3      389
# 37     383
# 0      382
# 39     345
# 30     342
# 2      315
# 7      300
# 40     267
# 1      242
# 27     236
# 9      218
# 5      111
# 6       32
# Name: BF, dtype: int64

# %%
data.head()
# Out:
#              Player Name  Team  Runs  Matches  Inn  No    HS    AVG   BF  \
# 0          Sai Sudharsan    GT   759       15   15   1  108*  54.21  486
# 1      Surya Kumar Yadav    MI   717       16   16   5   73*  65.18  427
# 2            Virat Kohli   RCB   657       15   15   3   73*  54.75  454
# 3           Shubman Gill    GT   650       15   15   2   93*  50.00  417
# 4         Mitchell Marsh   LSG   627       13   13   0   117  48.23  383
# 5           Shreyas Iyer  PBKS   604       17   17   5   97*  50.33  345
# 6       Yashasvi Jaiswal    RR   559       14   14   1    75  43.00  350
# 7      Prabhsimran Singh  PBKS   549       17   17   0    91  32.29  342
# 8              K L Rahul    DC   539       13   13   3  112*  53.90  360
# 9            Jos Buttler    GT   538       14   13   4   97*  59.78  330
# 10       Nicholas Pooran   LSG   524       14   14   2   87*  43.67  267
# 11      Heinrich Klaasen   SRH   487       13   13   2  105*  44.27  282
# ...

# %%
sns.set(style = 'darkgrid')

top_sixers = df.groupby('Player Name')['6s'].sum().sort_values(ascending=False).head(5)
top_sixers

top_sixers.plot(kind='bar')
plt.title("Top 5 6s")
plt.xlabel("SR")
plt.ylabel("6s")
plt.xticks(rotation=45)
plt.show()

# %%
sns.set(style = 'darkgrid')

top_strikers = df.groupby('Player Name')['SR'].sum().sort_values(ascending=False).head(5)
top_strikers

top_strikers.plot(kind='bar')
plt.title("Top 5 6s")
plt.xlabel("Player Name")
plt.ylabel("SR")
plt.xticks(rotation=45)
plt.show()
